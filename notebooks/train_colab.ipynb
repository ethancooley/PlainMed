# %% [markdown]
# # PlainMed — LoRA training on Colab (free T4)
# Runtime > Change runtime type > T4 GPU, then run all cells.
# Exploration/training notebook only — not a graded deliverable.

# %%
# !git clone https://github.com/ecooley/plainmed.git
# %cd plainmed

# %%
# !pip install -q -r requirements.txt
# !pip install -q trl datasets scikit-learn

# %%
# Full pipeline: data -> features -> LoRA train. Writes models/plainmed-lora/
# !python setup.py

# %%
# Sanity check before/after on one sentence
# !python scripts/model.py predict "Prophylactic anticoagulation is indicated post-operatively." --base
# !python scripts/model.py predict "Prophylactic anticoagulation is indicated post-operatively."

# %%
# Download the trained adapter to commit it to the repo / push to your Space
from google.colab import files
# !cd models && zip -r plainmed-lora.zip plainmed-lora
files.download('models/plainmed-lora.zip')
